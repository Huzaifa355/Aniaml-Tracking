# %%
import os
from PIL import Image

source_dir = r'D:\iot project\Animal_Dataset'
dest_dir = r'D:\iot project\resized'

IMG_SIZE = (224, 224)  # width, height

os.makedirs(dest_dir, exist_ok=True)

for class_name in os.listdir(source_dir):
    class_src_path = os.path.join(source_dir, class_name)
    if not os.path.isdir(class_src_path):
        continue  # skip files in source_dir if any
    class_dest_path = os.path.join(dest_dir, class_name)
    os.makedirs(class_dest_path, exist_ok=True)

    for img_name in os.listdir(class_src_path):
        img_src_path = os.path.join(class_src_path, img_name)
        img_dest_path = os.path.join(class_dest_path, img_name)

        try:
            with Image.open(img_src_path) as img:
                img = img.convert('RGB')
                img_resized = img.resize(IMG_SIZE, Image.Resampling.LANCZOS)
                img_resized.save(img_dest_path)
            print(f"Processed {img_src_path}")
        except Exception as e:
            print(f"Skipping {img_src_path}, error: {e}")

print("Images resized and saved to", dest_dir)
# Out:
# Processed D:\iot project\Animal_Dataset\Cow\1.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\2.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\3.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\4.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\43.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\5.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\6.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\7.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\8.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\9.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\cow-354428_1280.jpg
# Processed D:\iot project\Animal_Dataset\Cow\cow-4269568_1280.jpg
# Processed D:\iot project\Animal_Dataset\Cow\download (2).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\download (3).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\download (4).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\download (5).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\download (6).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\download (7).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (1).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (10).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (11).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (12).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (13).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (14).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (2).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (3).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (4).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (5).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (6).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (7).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (8).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images (9).jpeg
# Processed D:\iot project\Animal_Dataset\Cow\images.jpeg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-104783195-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-106511646-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-106531788-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-1137938028-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-1139848925-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-1290991984-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-1452842245-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-157328308-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-175770291-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-175898435-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-181584679-612x612 (1).jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-182815145-612x612.webp
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-1860999077-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-470788346-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-486140075-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-522580249-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-927110288-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Cow\istockphoto-970077862-612x612.jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (10).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (11).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (12).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (13).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (14).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (15).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (2).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\download (28).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (29).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (3).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\download (30).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (31).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (33).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (34).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (35).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (4).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\download (4).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (5).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\download (5).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download (8).jpg
# Processed D:\iot project\Animal_Dataset\Goat\download.jpg
# Processed D:\iot project\Animal_Dataset\Goat\DSC_0184__49429.jpg
# Processed D:\iot project\Animal_Dataset\Goat\DSC_0415__85304.jpg
# Processed D:\iot project\Animal_Dataset\Goat\DSC_0417__84581.jpg
# Processed D:\iot project\Animal_Dataset\Goat\DSC_0418__23065.jpg
# Processed D:\iot project\Animal_Dataset\Goat\DSC_0419__23807.jpg
# Processed D:\iot project\Animal_Dataset\Goat\DSC_0420__82444.jpg
# Processed D:\iot project\Animal_Dataset\Goat\DSC_0502__63572.jpg
# Processed D:\iot project\Animal_Dataset\Goat\H2ee7c85ed91a4ff7a6575334f0341e64p.jpg
# Processed D:\iot project\Animal_Dataset\Goat\il_570xN.2674039494_yavb.jpg
# Processed D:\iot project\Animal_Dataset\Goat\images (1).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\images (1).jpg
# Processed D:\iot project\Animal_Dataset\Goat\images (2).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\images (24).jpg
# Processed D:\iot project\Animal_Dataset\Goat\images (3).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\images (3).jpg
# Processed D:\iot project\Animal_Dataset\Goat\images (4).jpeg
# Processed D:\iot project\Animal_Dataset\Goat\images.jpeg
# Processed D:\iot project\Animal_Dataset\Goat\s-l1200 (1).jpg
# Processed D:\iot project\Animal_Dataset\Goat\s-l1200.jpg
# Processed D:\iot project\Animal_Dataset\Goat\s-l1600 (1).jpg
# Processed D:\iot project\Animal_Dataset\Goat\s-l1600.jpg
# Processed D:\iot project\Animal_Dataset\Goat\s-l400 (2).jpg
# Processed D:\iot project\Animal_Dataset\Goat\s-l400 (3).jpg
# Processed D:\iot project\Animal_Dataset\Goat\s-l400 (6).jpg
# Processed D:\iot project\Animal_Dataset\Goat\s-l400.jpg
# Processed D:\iot project\Animal_Dataset\Goat\sheep-toy-isolated-white-two-background-40187503.jpg
# Processed D:\iot project\Animal_Dataset\Goat\tbefjwdceedssxp9yhtq.png
# Processed D:\iot project\Animal_Dataset\Goat\toy-plastic-sheep-cut-out-on-white-2PJARJF.jpg
# Processed D:\iot project\Animal_Dataset\Goat\Toymany_Standing_Light-Haired_Ewe_Figurine_Toy-front.jpg
# Processed D:\iot project\Animal_Dataset\Hen\download (1).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (10).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (2).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (3).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (4).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (6).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (7).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (8).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download (9).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\download.jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (1).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (10).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (11).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (12).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (13).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (14).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (15).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (16).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (17).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (18).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (19).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (2).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (20).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (21).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (23).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (24).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (25).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (26).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (27).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (28).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (29).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (3).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (30).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (31).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (32).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (33).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (34).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (35).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (36).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (37).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (38).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (39).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (4).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (42).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (43).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (5).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (6).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images (7).jpeg
# Processed D:\iot project\Animal_Dataset\Hen\images.jpeg
# Processed D:\iot project\Animal_Dataset\Hen\s-l400.png
# Images resized and saved to D:\iot project\resized

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import numpy as np

# Paths
input_dir = r'D:\iot project\resized'  # Original images in class folders: cow/, goat/, camel/
output_dir = r'D:\iot project\Augmented1'  # Augmented image output path

# ImageDataGenerator for augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

# Image size
img_height, img_width = 224,224

# Augmentation loop
for class_name in os.listdir(input_dir):
    class_input_path = os.path.join(input_dir, class_name)
    class_output_path = os.path.join(output_dir, class_name)
    os.makedirs(class_output_path, exist_ok=True)

    for img_name in os.listdir(class_input_path):
        img_path = os.path.join(class_input_path, img_name)
        image = cv2.imread(img_path)
        image = cv2.resize(image, (img_width, img_height))
        image = np.expand_dims(image, 0)

        # Generate 5 augmented images per original
        aug_iter = datagen.flow(image, batch_size=1)
        for i in range(5):
            aug_image = next(aug_iter)[0].astype(np.uint8)
            aug_img_path = os.path.join(class_output_path, f"{os.path.splitext(img_name)[0]}_aug{i}.jpg")
            cv2.imwrite(aug_img_path, aug_image)

print("Data augmentation complete.")
# Out:
# Data augmentation complete.

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Single input folder and output folder
input_dir = r'D:\iot project\Hen'
output_dir = r'D:\iot project\Augmented'

# Image size
img_height, img_width = 96, 96

# Create output folder if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Image augmentation configuration
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

# Augment each image
for img_name in os.listdir(input_dir):
    img_path = os.path.join(input_dir, img_name)

    try:
        image = cv2.imread(img_path)
        if image is None:
            print(f"Skipping unreadable image: {img_path}")
            continue

        image = cv2.resize(image, (img_width, img_height))
        image = np.expand_dims(image, 0)

        aug_iter = datagen.flow(image, batch_size=1)

        # Generate 5 augmented images per original
        for i in range(5):
            aug_image = next(aug_iter)[0].astype(np.uint8)
            aug_img_name = f"{os.path.splitext(img_name)[0]}_aug{i}.jpg"
            aug_img_path = os.path.join(output_dir, aug_img_name)
            cv2.imwrite(aug_img_path, aug_image)

    except Exception as e:
        print(f"Error processing {img_path}: {e}")

print("Augmentation complete.")
# Out:
# Augmentation complete.
